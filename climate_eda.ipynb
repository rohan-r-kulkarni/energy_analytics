# %%
import numpy as np
import pandas as pd

# %%
coal = pd.read_csv("coal_consumption.csv")
coal.head(50)
# Out:
#                              Total consumption - COAL  Unnamed: 1  \
# 0   https://www.eia.gov/coal/data/browser/#/topic/...         NaN
# 1   Wed Mar 22 2023 18:09:54 GMT-0400 (Eastern Day...         NaN
# 2      Source: U.S. Energy Information Administration         NaN
# 3                                         description       units
# 4                                   Total consumption  short tons
# 5                                      Electric power  short tons
# 6                      Electric power : United States  short tons
# 7                        Electric power : New England  short tons
# 8                        Electric power : Connecticut  short tons
# 9                              Electric power : Maine  short tons
# 10                     Electric power : Massachusetts  short tons
# 11                     Electric power : New Hampshire  short tons
# 12                      Electric power : Rhode Island  short tons
# ...

# %%
gas_price = pd.read_csv("gas_price.csv")
gas_price.head(50)
gas_price.loc[1, :]
# Out:
# Back to Contents                                                             Date
# Data 1: Regular Conventional    Weekly U.S. Regular Conventional Retail Gasoli...
# Unnamed: 2                      Weekly East Coast Regular Conventional Retail ...
# Unnamed: 3                      Weekly New England (PADD 1A) Regular Conventio...
# Unnamed: 4                      Weekly Central Atlantic (PADD 1B) Regular Conv...
# Unnamed: 5                      Weekly Lower Atlantic (PADD 1C) Regular Conven...
# Unnamed: 6                      Weekly Midwest Regular Conventional Retail Gas...
# Unnamed: 7                      Weekly Gulf Coast Regular Conventional Retail ...
# Unnamed: 8                      Weekly Rocky Mountain Regular Conventional Ret...
# Unnamed: 9                      Weekly West Coast Regular Conventional Retail ...
# Unnamed: 10                     Weekly Colorado Regular Conventional Retail Ga...
# ...

# %%
net_gen = pd.read_csv("net_energy_gen.csv")
net_gen.loc[100:150,:]
# Out:
#                      Net generation for all sectors              Unnamed: 1  \
# 100         Massachusetts : all utility-scale solar  thousand megawatthours
# 101                      Massachusetts : geothermal  thousand megawatthours
# 102                         Massachusetts : biomass  thousand megawatthours
# 103     Massachusetts : wood and wood-derived fuels  thousand megawatthours
# 104                   Massachusetts : other biomass  thousand megawatthours
# 105   Massachusetts : hydro-electric pumped storage  thousand megawatthours
# 106                           Massachusetts : other  thousand megawatthours
# 107                       Massachusetts : all solar  thousand megawatthours
# 108  Massachusetts : small-scale solar photovoltaic  thousand megawatthours
# 109         Massachusetts : all utility-scale solar  thousand megawatthours
# 110                                   New Hampshire                     NaN
# ...

# %%
efuel = pd.read_csv("efuel_consumption.csv")

# %%
resp = pd.read_csv("resp.tsv", sep='\t')
resp.head(50)
# Out:
#    Notes    State  State Code       Month Month Code  Deaths      Population  \
# 0    NaN  Alabama         1.0  Jan., 1999    1999/01   453.0  Not Applicable
# 1    NaN  Alabama         1.0  Feb., 1999    1999/02   381.0  Not Applicable
# 2    NaN  Alabama         1.0  Mar., 1999    1999/03   574.0  Not Applicable
# 3    NaN  Alabama         1.0  Apr., 1999    1999/04   415.0  Not Applicable
# 4    NaN  Alabama         1.0   May, 1999    1999/05   330.0  Not Applicable
# 5    NaN  Alabama         1.0  Jun., 1999    1999/06   276.0  Not Applicable
# 6    NaN  Alabama         1.0  Jul., 1999    1999/07   300.0  Not Applicable
# 7    NaN  Alabama         1.0  Aug., 1999    1999/08   284.0  Not Applicable
# 8    NaN  Alabama         1.0  Sep., 1999    1999/09   260.0  Not Applicable
# 9    NaN  Alabama         1.0  Oct., 1999    1999/10   285.0  Not Applicable
# 10   NaN  Alabama         1.0  Nov., 1999    1999/11   306.0  Not Applicable
# ...
