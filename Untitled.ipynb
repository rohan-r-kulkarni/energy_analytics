# %%
import pandas as pd

# %%
import os
os.listdir(".")
# Out:
# ['.DS_Store',
#  'Untitled.ipynb',
#  'clean_gasprice.csv',
#  'raw_data',
#  'README.md',
#  'energy_cleaning.py',
#  '.ipynb_checkpoints',
#  '.git',
#  'climate_eda.ipynb']

# %%
pd.read_csv("clean_data/clean_Wood_gen.csv").set_index("Unnamed: 0")
# Out:
#             Alabama  Arkansas  California  Florida  Georgia  Idaho  Kentucky  \
# Unnamed: 0
# Q1 2001      361.00    126.67      256.00   146.33   255.33  43.67      1.00
# Q2 2001      334.00     96.67      264.67   161.33   249.33  45.67      1.00
# Q3 2001      351.33    129.67      302.00   143.00   240.67  51.67      1.00
# Q4 2001      344.33    148.00      285.00   159.33   245.67  36.67      1.00
# Q1 2002      347.67    145.00      330.00   126.67   265.00  34.67     32.00
# ...             ...       ...         ...      ...      ...    ...       ...
# Q4 2021      257.33     71.67      216.67   164.67   464.00  33.67     28.00
# Q1 2022      256.67     73.33      239.67   155.00   443.67  33.33     24.33
# Q2 2022      266.00     64.00      236.33   186.67   446.67  33.00     25.00
# Q3 2022      268.67     73.00      263.33   195.67   474.67  31.67     25.33
# Q4 2022      243.33     64.67      226.67   176.00   439.33  26.33     21.33
#
# ...
